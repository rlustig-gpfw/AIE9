# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
#model_endpoint = "accounts/fireworks/models/gpt-oss-20b"
model_endpoint = "accounts/ryl-junk-123-7tbkyo2/deployments/a80uegzj"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x117fc2fd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x117fc1a90>
# You’re asking the classic tongue‑twister that’s always been more for laughs than science.
# In “real” biology, there is no known “chuck” of wood that a wood‑chuck (the ground‑squirting *Marmota monax*) actually burrows, and literature never talks about a woodchuck *chuck*ing wood—so the only answers we have are either the silliness of the rhyme itself or the cheeky “chewing” that folks sometimes speculate.
#
# **Here are a few ways to read it:**
#
# | Interpretation | What it implies | A humorous take |
# |----------------|-----------------|------------------|
# | **Pure tongue‑twister** | The phrase is purposely nonsense; the answer is “as much as a woodchuck could chuck.” | **“All the wood it can get into its tiny jaws!”** |
# | **Scientific study (1978)** | A wildlife biologist, Richard Thomas, calculated that a woodchuck’s burrowing activity could move about **700 pounds of dirt** in a day; if it could chuck wood, it might move roughly the same amount. | **“A juggernaut of a chuck: roughly a yard‑long slab of pine, about 700 lbs of it!”** |
# | **Folk‑logic “chews about 1 cup of wood per bite”** | Imagine a woodchuck chomping on wood like a squirrel nuts. | **“If a woodchuck had the right mouth‑parts, it could chew up a little more than a barrel of mulch—before getting bored.”** |
#
# The most widely circulated “official” answer comes from the 1938 *New York Times* article quoting a research note: **“A woodchuck would chuck as much as a woodchuck would chuck if a woodchuck could chuck wood.”** That’s the one a lot of people (and AI) echo.
#
# ---
#
# ### Bottom line
#
# - If we take the tongue‑twister at face value: **“As much as it can, depending on the size of the wood.”**
# - If we extrapolate from the burrow‑weight study: **“About 700 pounds in a day”**—a decent amount of timber, though the real woodchuck only digs dirt.
#
# In either case, the fun is in the rhyme, not the math. So go ahead, say it three times fast and see how well you can keep your tongue out of a chuck!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 18: Ah, the classic tongue‑twister! According to folklore (and t...
# Response 16: Sure, I'd be happy to help! The classic answer is:
#
# > A wood...
# Response 4: It’s one of those classic riddles that’s more about the punc...
# Response 2: A classic tongue‑twister rather than a scientific fact—most ...
# Response 11: That classic riddle has more of a tongue‑twister charm than ...
# Response 22: The classic tongue‑twister doesn’t have a definitive answer,...
# Response 5: A classic tongue‑twister that’s more fun than fact! The popu...
# Response 15: The classic tongue‑twister doesn’t actually have a “one‑size...
# Response 17: Ah, the age‑old riddle that has tickled tongues and chuckled...
# Response 7: Sure thing! In a whimsical, foot‑loose version of the age‑ol...
# Response 10: **Answer (the classic tongue‑twister reply)**
# If a woodchu...
# Response 12: There’s no hard‑and‑fast rule for a woodchuck’s “chucking po...
# Response 9: Sure thing! In the classic sense, the answer is a playful bl...
# Response 3: A classic tongue‑twister, so the “official” answer is:
#
# > **...
# Response 6: **Short answer:**
# One “wood‑chuck” (the animal, *Marmota m...
# Response 21: In the spirit of the classic tongue‑twister, the most popula...
# Response 24: **Answer (Request #24)**
#
# The classic tongue‑twister doesn...
# Response 14: ### Short, Sweet (and Rhyme‑All‑in‑One)
#
# > “He would chuck *...
# Response 1: **Answer (Request 1)**
# A woodchuck would chuck **about 700...
# Response 23: A classic tongue‑twister answer: **“A wood‑chuck would chuck...
# Response 19: **Request 19 –**
# A classic tongue‑twister rather than a li...
# Response 20: **1. The Classic Explanation**
# A whiskey‑tasting woodchuck...
# Response 13: **Short answer:**
# A 1988 study by wildlife biologist Raymo...
# Response 8: **Answer**
# The classic question *“How much wood would a wo...
