# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # The Agent Loop: Building Production Agents with LangChain 1.0
#
# In this notebook, we'll explore the foundational concepts of AI agents and learn how to build production-grade agents using LangChain's new `create_agent` abstraction with middleware support.
#
# **Learning Objectives:**
# - Understand what an "agent" is and how the agent loop works
# - Learn the core constructs of LangChain (Runnables, LCEL)
# - Master the `create_agent` function and middleware system
# - Build an agentic RAG application using Qdrant
#
# ## Table of Contents:
#
# - **Breakout Room #1:** Introduction to LangChain, LangSmith, and `create_agent`
#   - Task 1: Dependencies
#   - Task 2: Environment Variables
#   - Task 3: LangChain Core Concepts (Runnables & LCEL)
#   - Task 4: Understanding the Agent Loop
#   - Task 5: Building Your First Agent with `create_agent()`
#   - Question #1 & Question #2
#   - Activity #1: Create a Custom Tool
#
# - **Breakout Room #2:** Middleware - Agentic RAG with Qdrant
#   - Task 6: Loading & Chunking Documents
#   - Task 7: Setting up Qdrant Vector Database
#   - Task 8: Creating a RAG Tool
#   - Task 9: Introduction to Middleware
#   - Task 10: Building Agentic RAG with Middleware
#   - Question #3 & Question #4
#   - Activity #2: Enhance the Agent

# %% [markdown]
# ---
# # 🤝 Breakout Room #1
# ## Introduction to LangChain, LangSmith, and `create_agent`

# %% [markdown]
# ## Task 1: Dependencies
#
# First, let's ensure we have all the required packages installed. We'll be using:
#
# - **LangChain 1.0+**: The core framework with the new `create_agent` API
# - **LangChain-OpenAI**: OpenAI model integrations
# - **LangSmith**: Observability and tracing
# - **Qdrant**: Vector database for RAG
# - **tiktoken**: Token counting for text splitting

# %%
# Run this cell to install dependencies (if not using uv sync)
# !pip install langchain>=1.0.0 langchain-openai langsmith langgraph qdrant-client langchain-qdrant tiktoken nest-asyncio

# %%
# Core imports we'll use throughout the notebook
import os
import getpass
from uuid import uuid4

import nest_asyncio
nest_asyncio.apply()  # Required for async operations in Jupyter

# %% [markdown]
# ## Task 2: Environment Variables
#
# We need to set up our API keys for:
# 1. **OpenAI** - For the GPT-5 model
# 2. **LangSmith** - For tracing and observability (optional but recommended)

# %%
import openai
from dotenv import load_dotenv

# Set OpenAI API Key
try:
    load_dotenv("..")
    openai_api_key = os.getenv("OPENAI_API_KEY")
except:
    openai.api_key = getpass.getpass("OpenAI API Key: ")
    os.environ["OPENAI_API_KEY"] = openai.api_key

# %%
# Optional: Set up LangSmith for tracing
# This provides powerful debugging and observability for your agents

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = f"AIE9 - The Agent Loop - {uuid4().hex[0:8]}"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("LangSmith API Key (press Enter to skip): ") or ""

if not os.environ["LANGCHAIN_API_KEY"]:
    os.environ["LANGCHAIN_TRACING_V2"] = "false"
    print("LangSmith tracing disabled")
else:
    print(f"LangSmith tracing enabled. Project: {os.environ['LANGCHAIN_PROJECT']}")
# Out:
# LangSmith tracing disabled

# %% [markdown]
# ## Task 3: LangChain Core Concepts
#
# Before diving into agents, let's understand the fundamental building blocks of LangChain.
#
# ### What is a Runnable?
#
# A **Runnable** is the core abstraction in LangChain - think of it as a standardized component that:
# - Takes an input
# - Performs some operation
# - Returns an output
#
# Every component in LangChain (models, prompts, retrievers, parsers) is a Runnable, which means they all share the same interface:
#
# ```python
# result = runnable.invoke(input)           # Single input
# results = runnable.batch([input1, input2]) # Multiple inputs
# for chunk in runnable.stream(input):       # Streaming
#     print(chunk)
# ```
#
# ### What is LCEL (LangChain Expression Language)?
#
# **LCEL** allows you to chain Runnables together using the `|` (pipe) operator:
#
# ```python
# chain = prompt | model | output_parser
# result = chain.invoke({"query": "Hello!"})
# ```
#
# This is similar to Unix pipes - the output of one component becomes the input to the next.

# %%
# Let's see LCEL in action with a simple example
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Create our components (each is a Runnable)
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that speaks like a pirate."),
    ("human", "{question}")
])

model = ChatOpenAI(model="gpt-5", temperature=0.7)

output_parser = StrOutputParser()

# Chain them together with LCEL
pirate_chain = prompt | model | output_parser

# %%
# Invoke the chain
response = pirate_chain.invoke({"question": "What is the capital of France?"})
print(response)
# Out:
# Arrr, that’d be Paris, matey!

# %% [markdown]
# ## Task 4: Understanding the Agent Loop
#
# ### What is an Agent?
#
# An **agent** is a system that uses an LLM to decide what actions to take. Unlike a simple chain that follows a fixed sequence, an agent can:
#
# 1. **Reason** about what to do next
# 2. **Take actions** by calling tools
# 3. **Observe** the results
# 4. **Iterate** until the task is complete
#
# ### The Agent Loop
#
# The core of every agent is the **agent loop**:
#
# ```
#                           AGENT LOOP
#
#       +----------+     +----------+     +----------+
#       |  Model   | --> |   Tool   | --> |  Model   | --> ...
#       |   Call   |     |   Call   |     |   Call   |
#       +----------+     +----------+     +----------+
#            |                                  |
#            v                                  v
#       "Use search"                   "Here's the answer"
# ```
#
# 1. **Model Call**: The LLM receives the current state and decides whether to:
#    - Call a tool (continue the loop)
#    - Return a final answer (exit the loop)
#
# 2. **Tool Call**: If the model decides to use a tool, the tool is executed and its output is added to the conversation
#
# 3. **Repeat**: The loop continues until the model decides it has enough information to answer
#
# ### Why `create_agent`?
#
# LangChain 1.0 introduced `create_agent` as the new standard way to build agents. It provides:
#
# - **Simplified API**: One function to create production-ready agents
# - **Middleware Support**: Hook into any point in the agent loop
# - **Built on LangGraph**: Uses the battle-tested LangGraph runtime under the hood

# %% [markdown]
# ## Task 5: Building Your First Agent with `create_agent()`
#
# Let's build a simple agent that can perform calculations and tell the time.
#
# ### Step 1: Define Tools
#
# Tools are functions that the agent can call. We use the `@tool` decorator to create them.

# %%
from langchain_core.tools import tool

@tool
def calculate(expression: str) -> str:
    """Evaluate a mathematical expression. Use this for any math calculations.
    
    Args:
        expression: A mathematical expression to evaluate (e.g., '2 + 2', '10 * 5')
    """
    try:
        # Using eval with restricted globals for safety
        result = eval(expression, {"__builtins__": {}}, {})
        return f"The result of {expression} is {result}"
    except Exception as e:
        return f"Error evaluating expression: {e}"

@tool
def get_current_time() -> str:
    """Get the current date and time. Use this when the user asks about the current time or date."""
    from datetime import datetime
    return f"The current date and time is: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}"

# Create our tool belt
tools = [calculate, get_current_time]

print("Tools created:")
for t in tools:
    print(f"  - {t.name}: {t.description[:60]}...")
# Out:
# Tools created:
#   - calculate: Evaluate a mathematical expression. Use this for any math ca...
#   - get_current_time: Get the current date and time. Use this when the user asks a...

# %% [markdown]
# ### Step 2: Create the Agent
#
# Now we use `create_agent` to build our agent. The function takes:
# - `model`: The LLM to use (can be a string like `"gpt-5"` or a model instance)
# - `tools`: List of tools the agent can use
# - `prompt`: Optional system prompt to customize behavior

# %%
from langchain.agents import create_agent

# Create our first agent
simple_agent = create_agent(
    model="gpt-5",
    tools=tools,
    system_prompt="You are a helpful assistant that can perform calculations and tell the time. Always explain your reasoning."
)

print("Agent created successfully!")
print(f"Type: {type(simple_agent)}")
# Out:
# Agent created successfully!
# Type: <class 'langgraph.graph.state.CompiledStateGraph'>

# %% [markdown]
# ### Step 3: Run the Agent
#
# The agent is a Runnable, so we can invoke it like any other LangChain component.

# %%
# Test the agent with a simple calculation
response = simple_agent.invoke(
    {"messages": [{"role": "user", "content": "What is 25 * 48?"}]}
)

# Print the final response
print("Agent Response:")
print(response["messages"][-1].content)
# Out:
# Agent Response:
# To calculate 25 × 48, I multiply the two numbers.
#
# 25 × 48 = 1200
#
# Another way to see it: 25 × 50 = 1250, then subtract 25 × 2 = 50, giving 1250 − 50 = 1200.

# %%
# Test with a multi-step question that requires multiple tool calls
response = simple_agent.invoke(
    {"messages": [{"role": "user", "content": "What time is it, and what is 100 divided by the current hour?"}]}
)

print("Agent Response:")
print(response["messages"][-1].content)
# Out:
# Agent Response:
# - Time: According to my system clock, it’s 22:48:32 on 2026-01-20.
# - 100 divided by the current hour: The hour is 22, so 100 ÷ 22 = 50/11 ≈ 4.5454545455.
#
# Reasoning: I read the current hour (22) from the time and divided 100 by 22. If you need the time in a specific timezone, tell me your location.

# %%
# Let's see the full conversation to understand the agent loop
print("Full Agent Conversation:")
print("=" * 50)
for msg in response["messages"]:
    role = msg.type if hasattr(msg, 'type') else 'unknown'
    content = msg.content if hasattr(msg, 'content') else str(msg)
    print(f"\n[{role.upper()}]")
    print(content[:500] if len(str(content)) > 500 else content)
# Out:
# Full Agent Conversation:
# ==================================================
#
# [HUMAN]
# What time is it, and what is 100 divided by the current hour?
#
# [AI]
#
#
# [TOOL]
# The current date and time is: 2026-01-20 22:48:32
#
# [AI]
#
#
# [TOOL]
# The result of 100 / 22 is 4.545454545454546
#
# [AI]
# - Time: According to my system clock, it’s 22:48:32 on 2026-01-20.
# - 100 divided by the current hour: The hour is 22, so 100 ÷ 22 = 50/11 ≈ 4.5454545455.
#
# Reasoning: I read the current hour (22) from the time and divided 100 by 22. If you need the time in a specific timezone, tell me your location.

# %% [markdown]
# ### Streaming Agent Responses
#
# For better UX, we can stream the agent's responses as they're generated.

# %%
# Stream the agent's response
print("Streaming Agent Response:")
print("=" * 50)

for chunk in simple_agent.stream(
    {"messages": [{"role": "user", "content": "Calculate 15% of 250"}]},
    stream_mode="updates"
):
    for node, values in chunk.items():
        print(f"\n[Node: {node}]")
        if "messages" in values:
            for msg in values["messages"]:
                if hasattr(msg, 'content') and msg.content:
                    print(msg.content)
# Out:
# Streaming Agent Response:
# ==================================================
#
# [Node: model]
#
# [Node: tools]
# The result of 0.15 * 250 is 37.5
#
# [Node: model]
# To find 15% of 250, multiply 250 by 0.15:
# 250 × 0.15 = 37.5
#
# Answer: 37.5

# %% [markdown]
# ---
# ## ❓ Question #1:
#
# In the agent loop, what determines whether the agent continues to call tools or returns a final answer to the user? How does `create_agent` handle this decision internally?
#
# ##### ✅ Answer:
# The agent stops calling tools when it determines it has enough info to answer the request. When a tool is called, a response is generated. The model will look at this response and determine if another tool is required to be called. If not, the response will be the final response.
#
# Internally, the `create_agent` decision happens in a similar manner. If the model's response (basically its analysis of the output) includes any further `tool_calls`, then is will execute those tools and continue the loop. Otherwise, if no tool calls, the model is done and returns the reponse to the user.

# %% [markdown]
# ## ❓ Question #2:
#
# Looking at the `calculate` and `get_current_time` tools we created, why is the **docstring** so important for each tool? How does the agent use this information when deciding which tool to call?
#
# ##### ✅ Answer:
# The **docstring** is used as context or key information for the agent to understand what the tool is and it's purpose. The more effective the docstring, the more accurate the tool call response based on the tool input.

# %% [markdown]
# ---
# ## 🏗️ Activity #1: Create a Custom Tool
#
# Create your own custom tool and add it to the agent!
#
# Ideas:
# - A tool that converts temperatures between Celsius and Fahrenheit
# - A tool that generates a random number within a range
# - A tool that counts words in a given text
#
# Requirements:
# 1. Use the `@tool` decorator
# 2. Include a clear docstring (this is what the agent sees!)
# 3. Add it to the agent and test it

# %%
import random

@tool
def celsius_to_fahrenheit(celsius: float) -> float:
    """Convert a temperature from Celsius to Fahrenheit. Use this tool when the user asks for a temperature in Fahrenheit."""
    return (celsius * 9/5) + 32

@tool
def fahrenheit_to_celsius(fahrenheit: float) -> float:
    """Convert a temperature from Fahrenheit to Celsius. Use this tool when the user asks for a temperature in Celsius."""
    return (fahrenheit - 32) * 5/9

@tool
def random_number(min: int, max: int) -> int:
    """Generate a random integer between a minimum and maximum integer value. Use this tool when the user asks for a random number."""
    return random.randint(min, max)

@tool
def word_count(text: str) -> int:
    """Count the number of words in a given text. Use this tool to count the number of words in a given text."""
    return len(text.split())


# Add tools to the tool list and create a new agent
tools = [celsius_to_fahrenheit, fahrenheit_to_celsius, random_number, word_count]

simple_agent = create_agent(
    model="gpt-5",
    tools=tools,
    system_prompt="You are a helpful assistant that can use tools to help the user with their questions."
)

# %%
response = simple_agent.invoke(
    {"messages": [{"role": "user", "content": "Convert 32 degrees fahrenheit to celsius."}]}
)
print(response["messages"][-1].content)

response = simple_agent.invoke(
    {"messages": [{"role": "user", "content": "Convert 100 degrees celsius to fahrenheit."}]}
)
print(response["messages"][-1].content)

response = simple_agent.invoke(
    {"messages": [{"role": "user", "content": "Generate a random number between 1 and 100."}]}
)
print(response["messages"][-1].content)

response = simple_agent.invoke(
    {"messages": [{"role": "user", "content": "Count the number of words in the following text: The small brown fox jumped over the lazy dog."}]}
)
print(response["messages"][-1].content)
# Out:
# 32°F is 0°C.
# 100°C is 212°F.
# 89
# 9

# %%
# Check that the agent can handle a multi-step question while using tools properly
for chunk in simple_agent.stream(
    {"messages": [{"role": "user", "content": "What is the average temperature in San Diego and what is this temperature in celsius?"}]},
    stream_mode="updates"
):
    for node, values in chunk.items():
        print(f"\n[Node: {node}]")
        if "messages" in values:
            for msg in values["messages"]:
                if hasattr(msg, 'content') and msg.content:
                    print(msg.content)
# Out:
# [Node: model]
#
# [Node: tools]
# 17.77777777777778
#
# [Node: model]
# About 64°F on average each year in San Diego, which is about 17.8°C.
# If you meant average highs/lows or a specific month, let me know.

# %% [markdown]
# ---
# # 🤝 Breakout Room #2
# ## Middleware - Agentic RAG with Qdrant

# %% [markdown]
# Now that we understand the basics of agents, let's build something more powerful: an **Agentic RAG** system.
#
# Traditional RAG follows a fixed pattern: retrieve → generate. But **Agentic RAG** gives the agent control over when and how to retrieve information, making it more flexible and intelligent.
#
# We'll also introduce **middleware** - hooks that let us customize the agent's behavior at every step.

# %% [markdown]
# ## Task 6: Loading & Chunking Documents
#
# We'll use the same Health & Wellness Guide from Session 2 to maintain continuity.

# %%
# Load the document using our aimakerspace utilities
from aimakerspace.text_utils import TextFileLoader, CharacterTextSplitter

# Load the document
text_loader = TextFileLoader("data/HealthWellnessGuide.txt")
documents = text_loader.load_documents()

print(f"Loaded {len(documents)} document(s)")
print(f"Total characters: {sum(len(doc) for doc in documents):,}")
# Out:
# Loaded 1 document(s)
# Total characters: 16,206

# %%
# Split the documents into chunks
text_splitter = CharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = text_splitter.split_texts(documents)

print(f"Split into {len(chunks)} chunks")
print(f"\nSample chunk:")
print("-" * 50)
print(chunks[0][:300] + "...")
# Out:
# Split into 41 chunks
#
# Sample chunk:
# --------------------------------------------------
# The Personal Wellness Guide
# A Comprehensive Resource for Health and Well-being
#
# PART 1: EXERCISE AND MOVEMENT
#
# Chapter 1: Understanding Exercise Basics
#
# Exercise is one of the most important things you can do for your health. Regular physical activity can improve your brain health, help manage weigh...

# %% [markdown]
# ## Task 7: Setting up Qdrant Vector Database
#
# Qdrant is a production-ready vector database. We'll use an in-memory instance for development, but the same code works with a hosted Qdrant instance.
#
# Key concepts:
# - **Collection**: A namespace for storing vectors (like a table in SQL)
# - **Points**: Individual vectors with optional payloads (metadata)
# - **Distance**: How similarity is measured (we'll use cosine similarity)

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

# Initialize the embedding model
embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

# Get embedding dimension
sample_embedding = embedding_model.embed_query("test")
embedding_dim = len(sample_embedding)
print(f"Embedding dimension: {embedding_dim}")
# Out:
# Embedding dimension: 1536

# %%
# Create Qdrant client (in-memory for development)
qdrant_client = QdrantClient(":memory:")

# Create a collection for our wellness documents
collection_name = "wellness_knowledge_base"

qdrant_client.create_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(
        size=embedding_dim,
        distance=Distance.COSINE
    )
)

print(f"Created collection: {collection_name}")
# Out:
# Created collection: wellness_knowledge_base

# %%
# Create the vector store and add documents
from langchain_core.documents import Document

# Convert chunks to LangChain Document objects
langchain_docs = [Document(page_content=chunk) for chunk in chunks]

# Create vector store
vector_store = QdrantVectorStore(
    client=qdrant_client,
    collection_name=collection_name,
    embedding=embedding_model
)

# Add documents to the vector store
vector_store.add_documents(langchain_docs)

print(f"Added {len(langchain_docs)} documents to vector store")
# Out:
# Added 41 documents to vector store

# %%
# Test the retriever
retriever = vector_store.as_retriever(search_kwargs={"k": 3})

test_results = retriever.invoke("How can I improve my sleep?")

print("Retrieved documents:")
for i, doc in enumerate(test_results, 1):
    print(f"\n--- Document {i} ---")
    print(doc.page_content[:200] + "...")
# Out:
# Retrieved documents:
#
# --- Document 1 ---
#  memory and learning
#
# Chapter 8: Improving Sleep Quality
#
# Sleep hygiene refers to habits and practices that promote consistent, quality sleep.
#
# Essential sleep hygiene practices:
# - Maintain a consiste...
#
# --- Document 2 ---
#  Avoid caffeine after 2 PM
# - Exercise regularly, but not too close to bedtime
# - Limit alcohol and heavy meals before bed
#
# Creating an optimal sleep environment:
# - Temperature: 65-68 degrees Fahrenheit...
#
# --- Document 3 ---
# de for sunlight
# 4. Power pose for 2 minutes
# 5. Healthy snack (nuts, fruit)
# 6. Brief walk around the block
# 7. Upbeat music
# 8. Splash cold water on face
#
# Sleep Checklist:
# - Room temperature 65-68F
# - Bla...

# %% [markdown]
# ## Task 8: Creating a RAG Tool
#
# Now we'll wrap our retriever as a tool that the agent can use. This is the key to **Agentic RAG** - the agent decides when to retrieve information.

# %%
from langchain_core.tools import tool

@tool
def search_wellness_knowledge(query: str) -> str:
    """Search the wellness knowledge base for information about health, fitness, nutrition, sleep, and mental wellness.
    
    Use this tool when the user asks questions about:
    - Physical health and fitness
    - Nutrition and diet
    - Sleep and rest
    - Mental health and stress management
    - General wellness tips
    
    Args:
        query: The search query to find relevant wellness information
    """
    results = retriever.invoke(query)
    
    if not results:
        return "No relevant information found in the wellness knowledge base."
    
    # Format the results
    formatted_results = []
    for i, doc in enumerate(results, 1):
        formatted_results.append(f"[Source {i}]:\n{doc.page_content}")
    
    return "\n\n".join(formatted_results)

print(f"Tool created: {search_wellness_knowledge.name}")
print(f"Description: {search_wellness_knowledge.description[:100]}...")
# Out:
# Tool created: search_wellness_knowledge
# Description: Search the wellness knowledge base for information about health, fitness, nutrition, sleep, and ment...

# %% [markdown]
# ## Task 9: Introduction to Middleware
#
# **Middleware** in LangChain 1.0 allows you to hook into the agent loop at various points:
#
# ```
#                        MIDDLEWARE HOOKS
#
#    +--------------+                    +--------------+
#    | before_model | --> MODEL CALL --> | after_model  |
#    +--------------+                    +--------------+
#
#    +-------------------+
#    | wrap_model_call   |  (intercept and modify calls)
#    +-------------------+
# ```
#
# Common use cases:
# - **Logging**: Track what the agent is doing
# - **Guardrails**: Filter or modify inputs/outputs
# - **Rate limiting**: Control API usage
# - **Human-in-the-loop**: Pause for human approval
#
# LangChain provides middleware through **decorator functions** that hook into specific points in the agent loop.

# %%
from langchain.agents.middleware import before_model, after_model

# Track how many model calls we've made
model_call_count = 0

@before_model
def log_before_model(state, runtime):
    """Called before each model invocation."""
    global model_call_count
    model_call_count += 1
    message_count = len(state.get("messages", []))
    print(f"[LOG] Model call #{model_call_count} - Messages in state: {message_count}")
    return None  # Return None to continue without modification

@after_model
def log_after_model(state, runtime):
    """Called after each model invocation."""
    last_message = state.get("messages", [])[-1] if state.get("messages") else None
    if last_message:
        has_tool_calls = hasattr(last_message, 'tool_calls') and last_message.tool_calls
        print(f"[LOG] After model - Tool calls requested: {has_tool_calls}")
    return None

print("Logging middleware created!")
# Out:
# Logging middleware created!

# %%
# You can also use the built-in ModelCallLimitMiddleware to prevent runaway agents
from langchain.agents.middleware import ModelCallLimitMiddleware

# This middleware will stop the agent after 10 model calls per thread
call_limiter = ModelCallLimitMiddleware(
    thread_limit=10,  # Max calls per conversation thread
    run_limit=5,      # Max calls per single run
    exit_behavior="end"  # What to do when limit is reached
)

print("Call limit middleware created!")
print(f"  - Thread limit: {call_limiter.thread_limit}")
print(f"  - Run limit: {call_limiter.run_limit}")
# Out:
# Call limit middleware created!
#   - Thread limit: 10
#   - Run limit: 5

# %% [markdown]
# ## Task 10: Building Agentic RAG with Middleware
#
# Now let's put it all together: an agentic RAG system with middleware support!

# %%
from langchain.agents import create_agent

# Reset the call counter
model_call_count = 0

# Define our tools - include the RAG tool and the calculator from earlier
rag_tools = [
    search_wellness_knowledge,
    calculate,
    get_current_time
]

# Create the agentic RAG system with middleware
wellness_agent = create_agent(
    model="gpt-5",
    tools=rag_tools,
    system_prompt="""You are a helpful wellness assistant with access to a comprehensive health and wellness knowledge base.

Your role is to:
1. Answer questions about health, fitness, nutrition, sleep, and mental wellness
2. Always search the knowledge base when the user asks wellness-related questions
3. Provide accurate, helpful information based on the retrieved context
4. Be supportive and encouraging in your responses
5. If you cannot find relevant information, say so honestly

Remember: Always cite information from the knowledge base when applicable.""",
    middleware=[
        log_before_model,
        log_after_model,
        call_limiter
    ]
)

print("Wellness Agent created with middleware!")
# Out:
# Wellness Agent created with middleware!

# %%
# Test the wellness agent
print("Testing Wellness Agent")
print("=" * 50)

response = wellness_agent.invoke(
    {"messages": [{"role": "user", "content": "What are some tips for better sleep?"}]}
)

print("\n" + "=" * 50)
print("FINAL RESPONSE:")
print("=" * 50)
print(response["messages"][-1].content)
# Out:
# Testing Wellness Agent
# ==================================================
# [LOG] Model call #1 - Messages in state: 1
# [LOG] After model - Tool calls requested: [{'name': 'search_wellness_knowledge', 'args': {'query': 'evidence-based tips for better sleep, sleep hygiene, insomnia prevention, circadian rhythm, screen time, caffeine, alcohol, exercise, bedroom environment, temperature, light exposure, relaxation techniques'}, 'id': 'call_miymo0AYBERZh9UpWD7xfwTv', 'type': 'tool_call'}]
# [LOG] Model call #2 - Messages in state: 3
# [LOG] After model - Tool calls requested: []
#
# ==================================================
# FINAL RESPONSE:
# ==================================================
# Here are evidence-based tips to improve sleep:
#
# - Keep a consistent sleep and wake time every day, even on weekends (Source 1).
# - Create a relaxing wind‑down routine (reading, gentle stretching, warm bath) before bed (Source 1).
# - Limit screens 1–2 hours before bedtime to reduce blue‑light stimulation (Sources 1–2).
# - Keep your bedroom cool, dark, and quiet:
#   - Temperature around 65–68°F (18–20°C)
#   - Use blackout curtains/sleep mask, and consider white noise or earplugs
#   - Ensure a comfortable mattress and pillows (Sources 2–3).
# - Avoid caffeine after 2 PM (Sources 1–3).
# - Limit alcohol and heavy meals close to bedtime (Source 3).
# - Exercise regularly, but not too close to bedtime (Sources 1, 3).
# - Keep a consistent pre-sleep checklist (e.g., room temp set, no screens, routine in place) to cue your body for sleep (Source 2).
#
# If sleep is still difficult after trying these for a few weeks—or you have issues like loud snoring, gasping, or persistent insomnia—consider discussing it with a healthcare professional.
#
# If you share your current routine (bedtime, screen use, caffeine, exercise, room setup), I can help tailor these tips to you.
#
# Sources: [Source 1], [Source 2], [Source 3]

# %%
# Test with a more complex query
print("Testing with complex query")
print("=" * 50)

response = wellness_agent.invoke(
    {"messages": [{"role": "user", "content": "I'm feeling stressed and having trouble sleeping. What should I do, and if I sleep 6 hours a night for a week, how many total hours is that?"}]}
)
print("\n" + "=" * 50)
print("FINAL RESPONSE:")
print("=" * 50)
print(response["messages"][-1].content)
# Out:
# Testing with complex query
# ==================================================
# [LOG] Model call #3 - Messages in state: 1
# [LOG] After model - Tool calls requested: [{'name': 'search_wellness_knowledge', 'args': {'query': 'Evidence-based ways to reduce stress and improve sleep: sleep hygiene checklist, CBT-I techniques (stimulus control, sleep restriction), relaxation (breathing, progressive muscle relaxation), mindfulness, exercise timing, caffeine/alcohol/screen limits, bedroom environment, consistent schedule, morning light, naps, worry time; recommended sleep duration for adults; when to seek professional help for insomnia or anxiety.'}, 'id': 'call_LqSqz8sYv5L2UirVoDm5PQP4', 'type': 'tool_call'}, {'name': 'calculate', 'args': {'expression': '6 * 7'}, 'id': 'call_Iqhp5lBMuZJXhdy8JOtB1Nf9', 'type': 'tool_call'}]
# [LOG] Model call #4 - Messages in state: 4
# [LOG] After model - Tool calls requested: []
#
# ==================================================
# FINAL RESPONSE:
# ==================================================
# I’m sorry you’re feeling stressed and having trouble sleeping. Here are evidence-based steps you can try:
#
# Immediate stress relief
# - Deep breathing: inhale for 4 counts, hold for 4, exhale for 4 [Source 3]
# - Progressive muscle relaxation: tense and release muscle groups from toes to head [Source 3]
# - Grounding (5-4-3-2-1): name 5 things you see, 4 you hear, 3 you feel, 2 you smell, 1 you taste [Source 3]
# - Take a short walk (ideally in nature) or listen to calming music [Source 3]
#
# Before bed tonight
# - Try relaxation techniques like progressive muscle relaxation, meditation, or deep breathing [Source 1][Source 2]
# - Consider a calming herbal tea such as chamomile or valerian root; some people use magnesium, but check with your healthcare provider first [Source 1][Source 2]
#
# If sleep trouble continues
# - Cognitive Behavioral Therapy for Insomnia (CBT-I) is an effective, non-drug approach for insomnia [Source 2]
# - Insomnia becomes “chronic” when it occurs at least 3 nights per week for 3 months or more; if that’s the case, consider seeing a healthcare professional or a CBT-I specialist [Source 2]
#
# Longer-term stress support
# - Regular exercise, adequate sleep, and staying socially connected help manage stress over time [Source 3]
#
# Your math: 6 hours a night for 7 nights = 42 hours total this week.
#
# If you’d like, I can guide you through a 2-minute breathing or muscle relaxation exercise now, or help you set a simple bedtime wind‑down plan.

# %%
# Test the agent's ability to know when NOT to use RAG
print("Testing agent decision-making (should NOT use RAG)")
print("=" * 50)

response = wellness_agent.invoke(
    {"messages": [{"role": "user", "content": "What is 125 * 8?"}]}
)

print("\n" + "=" * 50)
print("FINAL RESPONSE:")
print("=" * 50)
print(response["messages"][-1].content)
# Out:
# Testing agent decision-making (should NOT use RAG)
# ==================================================
# [LOG] Model call #5 - Messages in state: 1
# [LOG] After model - Tool calls requested: [{'name': 'calculate', 'args': {'expression': '125 * 8'}, 'id': 'call_BQlS7TAiq2hVdxuZsUGCv0X8', 'type': 'tool_call'}]
# [LOG] Model call #6 - Messages in state: 3
# [LOG] After model - Tool calls requested: []
#
# ==================================================
# FINAL RESPONSE:
# ==================================================
# 125 * 8 = 1000.

# %% [markdown]
# ### Visualizing the Agent
#
# The agent created by `create_agent` is built on LangGraph, so we can visualize its structure.

# %%
# Display the agent graph
try:
    from IPython.display import display, Image
    display(Image(wellness_agent.get_graph().draw_mermaid_png()))
except Exception as e:
    print(f"Could not display graph: {e}")
    print("\nAgent structure:")
    print(wellness_agent.get_graph().draw_ascii())

# %% [markdown]
# ---
# ## ❓ Question #3:
#
# How does **Agentic RAG** differ from traditional RAG? What are the advantages and potential disadvantages of letting the agent decide when to retrieve information?
#
# ##### ✅ Answer:
# Agentic RAG is a step towards agency along the control-agency spectrum where the agent now determine when and how to retrieve/use the information.
#
# One big advantage is a more flexible and adaptable workflow, with the agent deciding RAG calls based on user intent. Another advantage (when using something like ReAct) is multi-step reasoning. Rather than a simple retrieve and process workflow, the agent can iteratively retrieve and process information until it reaches a level of confidence to provide an accurate response. In a way, this seems very similar to how Cursor works with our codebases.
#
# The biggest disadvantage is false positive RAG calls, either retrieving data when it shouldn't or vice versa. This can waste money and provide wrong data to the user.

# %% [markdown]
# ## ❓ Question #4:
#
# Looking at the middleware examples (`log_before_model`, `log_after_model`, and `ModelCallLimitMiddleware`), describe a real-world scenario where middleware would be essential for a production agent. What specific middleware hooks would you use and why?
#
# ##### ✅ Answer:
# One scenario could be legal document approvals or production code deployments. In these cases, a human in the loop hook would be necessary where the "before model" hook would wait for human approval/rejection and the "after model" hook would log and/or proceed with the delivery of legal docs or code deployment.

# %% [markdown]
# ---
# ## 🏗️ Activity #2: Enhance the Agentic RAG System
#
# Now it's your turn! Enhance the wellness agent by implementing ONE of the following:
#
# ### Option A: Add a New Tool
# Create a new tool that the agent can use. Ideas:
# - A tool that calculates BMI given height and weight
# - A tool that estimates daily calorie needs
# - A tool that creates a simple workout plan
#
# ### Option B: Create Custom Middleware
# Build middleware that adds new functionality:
# - Middleware that tracks which tools are used most frequently
# - Middleware that adds a friendly greeting to responses
# - Middleware that enforces a response length limit
#
# ### Option C: Improve the RAG Tool
# Enhance the retrieval tool:
# - Add metadata filtering
# - Implement reranking of results
# - Add source citations with relevance scores

# %% [markdown]
# #### New Tools

# %%
# New Tool
@tool
def compute_bmi(height: float, weight: float) -> float:
    """Calculate the Body Mass Index (BMI) given a person's height and weight in inches and pounds.
    
    Args:
        height: The height of the person in inches
        weight: The weight of the person in pounds
    """
    bmi = weight / (height * height) * 703
    return bmi

# %% [markdown]
# #### Custom Middleware Functions

# %%
# Track tool usage frequency
tool_usage = dict()

@after_model
def count_tool_usage(state, runtime):
    """Count the number of times each tool is called."""
    last_message = state.get("messages", [])[-1] if state.get("messages") else None
    if last_message:
        # Check for tool calls
        has_tool_calls = hasattr(last_message, 'tool_calls') and last_message.tool_calls
        if has_tool_calls:
            # Count the number of tool calls if tool_name exists
            for tool_call in last_message.tool_calls:
                tool_name = tool_call.get("name")
                if not tool_name and isinstance(tool_call.get("function"), dict):
                    tool_name = tool_call["function"].get("name")

                if tool_name:
                    tool_usage[tool_name] = tool_usage.get(tool_name, 0) + 1
    return None

@after_model
def enforce_response_length(state, runtime):
    """Enforce a final response length limit"""
    # Get the last message
    last_message = state.get("messages", [])[-1]

    # Check if there are any tool calls
    tool_calls = getattr(last_message, "tool_calls", [])

    # If there are no tool calls, limit the response length
    if not tool_calls:
        max_chars = 500
        if len(last_message.content) > max_chars:
            # Force a hard limit to truncate the response
            last_message.content = last_message.content[:max_chars]
            print(f"Truncated response to {max_chars} characters")

    return None

# %%
@tool
def search_wellness_knowledge(query: str) -> str:
    """Search the wellness knowledge base for information about health, fitness, nutrition, sleep, and mental wellness.
    
    Use this tool when the user asks questions about:
    - Physical health and fitness
    - Nutrition and diet
    - Sleep and rest
    - Mental health and stress management
    - General wellness tips
        
    Args:
        query: The search query to find relevant wellness information
    """
    results_with_scores = vector_store.similarity_search_with_score(query, k=5)
    
    if not results_with_scores:
        return "No relevant information found in the wellness knowledge base."
    
    # Format the results
    formatted_results = []
    for i, (doc, score) in enumerate(results_with_scores, 1):
        source_file = doc.metadata.get("source", "Unknown File")
        page_number = doc.metadata.get("page", "Unknown Page")
        formatted_results.append(f"[Source {i}]:\n{doc.page_content}\nSource File: {source_file}\nPage/Chapter: {page_number}\nRelevance Score: {score:.2f}")
    
    return "\n\n".join(formatted_results)

# %% [markdown]
# Add metadata to the docs

# %%
langchain_docs = [
    Document(page_content=chunk, metadata={"source": "HealthWellnessGuide.txt"}) 
    for chunk in chunks
]

# Create vector store (rest of the cell remains the same)
vector_store = QdrantVectorStore(
    client=qdrant_client,
    collection_name=collection_name,
    embedding=embedding_model
)

# Add documents to the vector store
vector_store.add_documents(langchain_docs)

print(f"Added {len(langchain_docs)} documents to vector store")
# Out:
# Added 41 documents to vector store

# %% [markdown]
# #### Setup Agentic RAG Pipeline

# %%
# Reset the tool usage tracker
tool_usage = dict()

# Define rag tools
rag_tools = [
    search_wellness_knowledge,
    calculate,
    get_current_time,
    compute_bmi
]

# Create the agentic RAG system with middleware
wellness_agent = create_agent(
    model="gpt-5",
    tools=rag_tools,
    system_prompt="""You are a helpful wellness assistant with access to a comprehensive health and wellness knowledge base.

Your role is to:
1. Answer questions about health, fitness, nutrition, sleep, and mental wellness
2. Always search the knowledge base when the user asks wellness-related questions
3. Provide accurate, helpful information based on the retrieved context
4. Be supportive and encouraging in your responses
5. If you cannot find relevant information, say so honestly

Remember: Always cite information from the knowledge base when applicable.
Each line or summary in the response should be cited.
Include the source file name, page number or chapter, and relevance score in the citation.""",
    middleware=[
        count_tool_usage,
    ]
)

# %% [markdown]
# Run some tests on the update agent

# %%
# Test basic agent usage
response = wellness_agent.invoke(
    {"messages": [{"role": "user", "content": "What is the BMI for a person who is 70 inches tall and weighs 180 pounds?"}]}
)
print(response["messages"][-1].content)
# Test tool usage tracking
print("Tool usage frequency:")
print(tool_usage)
# Out:
# - Your BMI is 25.8 (calculated from 70 inches and 180 pounds). [No relevant knowledge-base source; direct calculation using internal BMI tool; citation not applicable]
#
# - Note: I searched our wellness knowledge base for BMI formula/categories but didn’t find a relevant entry to cite (Source File: Unknown File; Page/Chapter: N/A; Highest Relevance Score: 0.26).
# Tool usage frequency:
# {'search_wellness_knowledge': 2, 'compute_bmi': 1}

# %%
# Test agent for RAG call, ensuring source citations and relevance scores are
response = wellness_agent.invoke(
    {"messages": [{"role": "user", "content": "What are some tips for better sleep?"}]}
)

print(response["messages"][-1].content)
# Out:
# - Keep a consistent sleep and wake schedule, even on weekends. [HealthWellnessGuide.txt, Chapter 8: Improving Sleep Quality, 0.60]
# - Build a relaxing pre-bed routine (e.g., light reading, gentle stretching, warm bath). [HealthWellnessGuide.txt, Chapter 8: Improving Sleep Quality, 0.60]
# - Keep your bedroom cool, dark, and quiet; aim for about 65–68°F and consider blackout curtains or a sleep mask. [HealthWellnessGuide.txt, Unknown Page (Sleep Checklist), 0.58] [HealthWellnessGuide.txt, Chapter 8: Improving Sleep Quality, 0.60]
# - Limit screens before bed—at least 1 hour (ideally 1–2 hours) without devices. [HealthWellnessGuide.txt, Unknown Page (Sleep Checklist), 0.58] [HealthWellnessGuide.txt, Chapter 8: Improving Sleep Quality, 0.60]
# - Avoid caffeine after 2 PM. [HealthWellnessGuide.txt, Unknown Page (Sleep Checklist), 0.58] [HealthWellnessGuide.txt, Chapter 8: Improving Sleep Quality, 0.60]
# - Exercise regularly, but not too close to bedtime. [HealthWellnessGuide.txt, Chapter 8: Improving Sleep Quality, 0.60]
# - Limit evening alcohol; it can disrupt sleep quality. [HealthWellnessGuide.txt, Chapter 8: Improving Sleep Quality, 0.60]
# - Ensure your mattress and pillows are comfortable and supportive. [HealthWellnessGuide.txt, Unknown Page (Sleep Checklist), 0.58]
# - Aim for roughly 7–9 hours of sleep if possible. [HealthWellnessGuide.txt, Unknown Page (Daily Wellness Checklist), 0.58]

# %% [markdown]
# Update the agent with a additional middleware to limit response length

# %%
# Create the agentic RAG system with additional middleware
wellness_agent = create_agent(
    model="gpt-5",
    tools=rag_tools,
    system_prompt="""You are a helpful wellness assistant with access to a comprehensive health and wellness knowledge base.

Your role is to:
1. Answer questions about health, fitness, nutrition, sleep, and mental wellness
2. Always search the knowledge base when the user asks wellness-related questions
3. Provide accurate, helpful information based on the retrieved context
4. Be supportive and encouraging in your responses
5. If you cannot find relevant information, say so honestly

Remember: Always cite information from the knowledge base when applicable.
Each line or summary in the response should be cited.
Include the source file name, page number or chapter, and relevance score in the citation.""",
    middleware=[
        count_tool_usage,
        enforce_response_length
    ]
)

# %%
# Run same test as before to compare response length
response = wellness_agent.invoke(
    {"messages": [{"role": "user", "content": "What are some tips for better sleep?"}]}
)

print(response["messages"][-1].content)
# Out:
# Truncated response to 500 characters
# - Keep a consistent sleep and wake schedule, even on weekends. [Source: Unknown File, Chapter 8: Improving Sleep Quality, Relevance 0.59]
# - Build a relaxing wind-down routine 30–60 minutes before bed (dim lights, gentle stretching/yoga, warm bath/shower, journaling, or reading a paper book). [Source: Unknown File, Chapter 15: Evening Wind-Down Routines, Relevance 0.53; Unknown File, Chapter 8: Improving Sleep Quality, Relevance 0.59]
# - Make your bedroom sleep-friendly: cool (about 65–68°F / 18–2

# %%
display(Image(wellness_agent.get_graph().draw_mermaid_png()))
